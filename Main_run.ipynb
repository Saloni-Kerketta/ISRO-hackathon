# %%
# %run run_batch.py
# Out:
# (No folder given, defaulting to: graphs)
#
# Found 8548 .gpickle file(s). Processing...
#
#   ...processed 25/8548
#   ...processed 50/8548
#   ...processed 75/8548
#   ...processed 100/8548
#   ...processed 125/8548
#   ...processed 150/8548
#   ...processed 175/8548
#   ...processed 200/8548
#   ...processed 225/8548
#   ...processed 250/8548
#   ...processed 275/8548
#   ...processed 300/8548
#   ...processed 325/8548
#   ...processed 350/8548
#   ...processed 375/8548
#   ...processed 400/8548
#   ...processed 425/8548
#   ...processed 450/8548
#   ...processed 475/8548
#   ...processed 500/8548
#   ...processed 525/8548
#   ...processed 550/8548
#   ...processed 575/8548
#   ...processed 600/8548
#   ...processed 625/8548
#   ...processed 650/8548
#   ...processed 675/8548
#   ...processed 700/8548
#   ...processed 725/8548
#   ...processed 750/8548
#   ...processed 775/8548
#   ...processed 800/8548
#   ...processed 825/8548
#   ...processed 850/8548
#   ...processed 875/8548
# ...

# %%
# %%writefile .gitignore
# graphs/
# Out:
# Overwriting .gitignore

# %%
# !python generate_heatmaps.py graphs heatmap_outputs
# Out:
# (No filenames given, using DEFAULT_CANDIDATES list defined in this script)
#
# [1/15] Processing 653518_graph.gpickle...
# Saved map-style heatmap to: heatmap_outputs\653518_graph_map_heatmap.png
# Saved matrix-style heatmap to: heatmap_outputs\653518_graph_distance_matrix.png
# Saved interactive heatmap to: heatmap_outputs\653518_graph_interactive.html
#   -> 35 nodes, resilience precomputed for all nodes
# [2/15] Processing 906809_graph.gpickle...
# Saved map-style heatmap to: heatmap_outputs\906809_graph_map_heatmap.png
# Saved matrix-style heatmap to: heatmap_outputs\906809_graph_distance_matrix.png
# Saved interactive heatmap to: heatmap_outputs\906809_graph_interactive.html
#   -> 34 nodes, resilience precomputed for all nodes
# [3/15] Processing 883311_graph.gpickle...
# Saved map-style heatmap to: heatmap_outputs\883311_graph_map_heatmap.png
# Saved matrix-style heatmap to: heatmap_outputs\883311_graph_distance_matrix.png
# ...
